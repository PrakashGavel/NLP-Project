# %% [markdown]
# <a href="https://colab.research.google.com/github/PrakashGavel/NLP-Project/blob/main/Section_2_Copy_of_Text2MCQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installation of libraries

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install virtualenv
# !virtualenv /content/drive/MyDrive/colab_env
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 53.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 41.4 MB/s eta 0:00:00
# ...
# created virtual environment CPython3.9.16.final.0-64 in 23006ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/colab_env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
# ...

# %%
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install --quiet flashtext==2.7
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install git+https://github.com/boudinfl/pke.git
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install --quiet transformers==4.8.1
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install --quiet sentencepiece==0.1.95
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install --quiet textwrap3==0.9.2
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install --quiet gradio==3.0.20
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install googletrans==3.1.0a0
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install --quiet strsim==0.0.3
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install --quiet sense2vec==2.0.0
# !source /content/drive/MyDrive/colab_env/bin/activate; pip install --quiet sentence-transformers==2.2.2
#!source /content/drive/MyDrive/colab_env/bin/activate; pip install

# %%
import sys
sys.path.append("/content/drive/MyDrive/colab_env/lib/python3.9/site-packages")
# Out:
# time: 601 µs (started: 2023-04-13 17:45:55 +00:00)

# %%
# !pip install --quiet ipython-autotime
# %load_ext autotime
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.0 MB/s eta 0:00:00
# time: 816 µs (started: 2023-04-13 16:53:27 +00:00)

# %%
# !pip install --quiet flashtext==2.7
# !pip install git+https://github.com/boudinfl/pke.git
# !pip install --quiet transformers==4.8.1
# !pip install --quiet sentencepiece==0.1.95
# !pip install --quiet textwrap3==0.9.2
# !pip install --quiet gradio==3.0.20
# !pip install googletrans==3.1.0a0
# !pip install --quiet strsim==0.0.3
# !pip install --quiet sense2vec==2.0.0
# !pip install --quiet ipython-autotime
# %load_ext autotime
# !pip install --quiet sentence-transformers==2.2.2

# %%
# import os  # no need to run
# os.kill(os.getpid(), 9)

# %% [markdown]
# ## Example 1

# %% [markdown]
# Text taken from: https://gadgets.ndtv.com/internet/news/dogecoin-price-rally-surge-elon-musk-tweet-twitter-working-developers-improve-transaction-efficiency-2442120

# %%
# htext = """एलोन मस्क ने फिर से दिखाया है कि वह सिर्फ अपने ट्वीट्स से डिजिटल मुद्रा बाजार को प्रभावित कर सकते हैं। यह कहने के बाद उनकी इलेक्ट्रिक वाहन बनाने वाली कंपनी
# पर्यावरणीय चिंताओं के कारण टेस्ला बिटकॉइन में भुगतान स्वीकार नहीं करेगा, उन्होंने ट्वीट किया कि वह सुधार के लिए डॉगकोइन के डेवलपर्स के साथ काम कर रहे थे
# सिस्टम लेनदेन दक्षता। उनके दो अलग-अलग बयानों के बाद, दुनिया की सबसे बड़ी क्रिप्टोकरेंसी दो महीने के निचले स्तर पर आ गई, जबकि डॉगकॉइन
# करीब 20 फीसदी की तेजी आई। स्पेसएक्स के सीईओ ने हाल के महीनों में अक्सर डॉगकोइन के समर्थन में ट्वीट किया है, लेकिन बिटकॉइन के लिए शायद ही कभी। हाल ही में एक ट्वीट में,
# मस्क ने टेस्ला से एक बयान दिया कि वह बिटकॉइन (भारत में कीमत) खनन के लिए जीवाश्म ईंधन के तेजी से बढ़ते उपयोग के बारे में "चिंतित" था और
# लेन-देन, और इसलिए क्रिप्टोक्यूरेंसी का उपयोग करके वाहन खरीद को निलंबित कर रहा था। एक दिन बाद उन्होंने फिर से ट्वीट किया, "स्पष्ट होने के लिए, मैं दृढ़ता से
# क्रिप्टो में विश्वास करते हैं, लेकिन यह जीवाश्म ईंधन के उपयोग, विशेष रूप से कोयले में भारी वृद्धि नहीं कर सकता है। इसने बिटकॉइन मूल्य के लिए एक नीचे की ओर सर्पिल ट्रिगर किया लेकिन
# तब से क्रिप्टोक्यूरेंसी स्थिर हो गई है। कई ट्विटर यूजर्स ने मस्क के बयान का स्वागत किया। उनमें से एक ने कहा कि यह समय लोगों को समझने का है
# कि डॉगकोइन "यहाँ रहने के लिए है" और दूसरे ने मस्क के पिछले दावे को संदर्भित किया कि क्रिप्टो दुनिया की भविष्य की मुद्रा बन सकती है। """

htext = """मैं एक मामूली औरत हूँ। इतनी मामूली हूँ कि आपकी नज़र भी मुझ पर नहीं पड़ी लेकिन मैं आपको देख रही हूँ।

आप अपनी बीवी के साथ डाक्टर के यहाँ जा रहे हैं। उसकी कोख में लड़की या लड़का, यह जानने के लिए।

असल में आप अपनी लड़की की हत्या करना चाहते हैं, कोख में ही।

आपको यह ख़याल भी नहीं आ सकता कि जिस सड़क से आप जा रहे हैं उसे मैंने बनाया है।

मैंने यहाँ रोड़ियाँ बिछाईं और फिर उन्हें दुर्मुट से कूटा था।

मेरी छोटी बेटी तब यहाँ किनारे पर उगी झाड़ियों में ऊँघती रहती थी।

मेरी तीन बेटियाँ हैं।

मेरा आदमी कहता था कि अगर बेटा नहीं हुआ तो मुझे छोड़ देगा। उसने कहने के लिए मुझे छोड़ भी दिया पर अब भी पका-पकाया खाने के लिए जब-तब आ जाता है।

बस कहीं और काम मिला तो ये जगह छोड़ दूँगी। देखूँ तब तक तो यहीं काम करना पड़ेगा ।

मैं पढ़ी-लिखी होती तो ये ही सब बातें लिख देती।

फिर तो तुम भी मेरी बात किताब में पढ़ लेते।

पढ़कर तुम भी कहते कर्तारी देवी बात तो पते की कहती है। """

htext = htext.replace('\n', ' ')

from googletrans import Translator
translater = Translator()
text1 = translater.translate(htext, dest="en")
text = text1.text
print(text)
# Out:
# I am a modest woman. I am so modest that even your eyes did not fall on me but I am seeing you. You are going to the doctor with your wife. To know whether it is a girl or a boy in her womb. Actually you want to kill your girl child, in the womb itself. It cannot even occur to you that I have made the road by which you are going. I laid stones here and then pounded them with a mortar. My little daughter then used to doze in the bushes growing on the bank here. I have three daughters. My man used to say that if I do not have a son, he will leave me. He even left me to say but still comes every now and then to eat cooked food. If I get work elsewhere, I will leave this place. Till then I will have to work here. Had I been educated, I would have written all these things. Then you too would have read my words in the book. After reading you also say Kartari Devi, the matter tells about the address.
# time: 226 ms (started: 2023-04-13 18:09:06 +00:00)

# %% [markdown]
# # **Summarization with T5**

# %%
import torch
from transformers import T5ForConditionalGeneration,T5Tokenizer
summary_model = T5ForConditionalGeneration.from_pretrained('t5-base')
summary_tokenizer = T5Tokenizer.from_pretrained('t5-base')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
summary_model = summary_model.to(device)
# Out:
# Downloading:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# time: 1min 17s (started: 2023-04-13 17:08:48 +00:00)

# %%
import random
import numpy as np

def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)
# Out:
# time: 2.18 ms (started: 2023-04-13 17:10:08 +00:00)

# %%
from textwrap3 import wrap
import nltk
nltk.download('punkt')
nltk.download('brown')
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
from nltk.tokenize import sent_tokenize

def postprocesstext (content):
  final=""
  for sent in sent_tokenize(content):
    sent = sent.capitalize()
    final = final +" "+sent
  return final


def summarizer(text,model,tokenizer):
  text = text.strip().replace("\n"," ")
  text = "summarize: "+text
  # print (text)
  max_len = 512
  encoding = tokenizer.encode_plus(text,max_length=max_len, pad_to_max_length=False,truncation=True, return_tensors="pt").to(device)

  input_ids, attention_mask = encoding["input_ids"], encoding["attention_mask"]

  outs = model.generate(input_ids=input_ids,
                                  attention_mask=attention_mask,
                                  early_stopping=True,
                                  num_beams=3,
                                  num_return_sequences=1,
                                  no_repeat_ngram_size=2,
                                  min_length = 75,
                                  max_length=300)


  dec = [tokenizer.decode(ids,skip_special_tokens=True) for ids in outs]
  summary = dec[0]
  summary = postprocesstext(summary)
  summary= summary.strip()

  return summary


summarized_text = summarizer(text,summary_model,summary_tokenizer)


print ("\noriginal Text >>")
for wrp in wrap(text, 150):
  print (wrp)
print ("\n")
print ("Summarized Text >>")
for wrp in wrap(summarized_text, 150):
  print (wrp)
print ("\n")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# original Text >>
# Elon Musk has shown again that he can influence the digital currency market with just his tweets. After saying that his electric vehicle maker Tesla
# would no longer accept payments in bitcoin due to environmental concerns, tweeting that it was working with Dogecoin's developers to improve System
# transaction efficiency. Following his two separate statements, the world's largest cryptocurrency fell to a two-month low, while Dogecoin There was an
# increase of about 20 percent. The SpaceX CEO has tweeted frequently in recent months in support of Dogecoin, but rarely for bitcoin. In a recent
# ...

# %% [markdown]
# # **Answer Span Extraction (Keywords and Noun Phrases)**

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import string
import pke
import traceback

def get_nouns_multipartite(content):
    out=[]
    try:
        extractor = pke.unsupervised.MultipartiteRank()
        extractor.load_document(input=content,language='en')
        #    not contain punctuation marks or stopwords as candidates.
        pos = {'PROPN','NOUN'}
        #pos = {'PROPN','NOUN'}
        stoplist = list(string.punctuation)
        stoplist += ['-lrb-', '-rrb-', '-lcb-', '-rcb-', '-lsb-', '-rsb-']
        stoplist += stopwords.words('english')
        # extractor.candidate_selection(pos=pos, stoplist=stoplist)
        extractor.candidate_selection(pos=pos)
        # 4. build the Multipartite graph and rank candidates using random walk,
        #    alpha controls the weight adjustment mechanism, see TopicRank for
        #    threshold/method parameters.
        extractor.candidate_weighting(alpha=1.1,
                                      threshold=0.75,
                                      method='average')
        keyphrases = extractor.get_n_best(n=15)
        

        for val in keyphrases:
            out.append(val[0])
    except:
        out = []
        traceback.print_exc()

    return out
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# time: 22.9 s (started: 2023-04-13 17:10:36 +00:00)

# %%
# from googletrans import Translator
# from transformers.pipelines import text2text_generation
# from flashtext import KeywordProcessor

# def get_keywords(originaltext,summarytext):
#   texteng1 = get_nouns_multipartite(originaltext)
#   print ("keywords unsummarized in english: ",texteng1)

#   # Convert the list of keywords into a string
#   keyword_str = ', '.join(texteng1)

#   translater = Translator()
#   keywords = translater.translate(keyword_str, dest="hi")
#   print("keywords unsummarized in hindi: ",keywords.text)

#   keyword_processor = KeywordProcessor()
#   for keyword in texteng1:
#     keyword_processor.add_keyword(keyword)

#   texteng2 = keyword_processor.extract_keywords(summarytext)
#   texteng2 = list(set(texteng2))
#   print ("keywords_found in summarized in english: ",texteng2)

#   # Convert the list of keywords_found into a string
#   keywords_found_str = ', '.join(texteng2)

#   translater = Translator()
#   keywords_found = translater.translate(keywords_found_str, dest="hi")
#   print("keywords_found in summarized in hindi: ",keywords_found.text)

#   important_keywords =[]
#   for keyword in texteng1:
#     if keyword in texteng2:
#       important_keywords.append(keyword)

#   return important_keywords[:4]


# texteng3 = get_keywords(text,summarized_text)
# print ("imp keywords in english:", texteng3)

# # Convert the list of keywords_found into a string
# keywords_found_str = ', '.join(texteng3)

# translater = Translator()
# imp_keywords = translater.translate(keywords_found_str, dest="hi")
# print("imp keywords in hindi:", imp_keywords.text)


from flashtext import KeywordProcessor


def get_keywords(originaltext,summarytext):
  keywords = get_nouns_multipartite(originaltext)
  print ("keywords unsummarized: ",keywords)
  keyword_processor = KeywordProcessor()
  for keyword in keywords:
    keyword_processor.add_keyword(keyword)

  keywords_found = keyword_processor.extract_keywords(summarytext)
  keywords_found = list(set(keywords_found))
  print ("keywords_found in summarized: ",keywords_found)

  important_keywords =[]
  for keyword in keywords:
    if keyword in keywords_found:
      important_keywords.append(keyword)

  return important_keywords[:4]


imp_keywords = get_keywords(text,summarized_text)
print (imp_keywords)
# Out:
# keywords unsummarized:  ['elon musk', 'dogecoin', 'bitcoin', 'statements', 'tesla', 'tweets', 'cryptocurrency', 'vehicle maker', 'musk', 'currency market', 'system transaction efficiency', 'price', 'fuels', 'world', 'payments']
# keywords_found in summarized:  ['elon musk', 'world', 'dogecoin', 'tweets', 'bitcoin', 'cryptocurrency']
# ['elon musk', 'dogecoin', 'bitcoin', 'tweets']
# time: 2.9 s (started: 2023-04-13 17:10:59 +00:00)

# %% [markdown]
# # **Question generation with T5**

# %%
# question_model = T5ForConditionalGeneration.from_pretrained('ramsrigouthamg/t5_squad_v1')
# question_tokenizer = T5Tokenizer.from_pretrained('ramsrigouthamg/t5_squad_v1')
question_model = T5ForConditionalGeneration.from_pretrained('/content/drive/MyDrive/T5/model/')
question_tokenizer = T5Tokenizer.from_pretrained('/content/drive/MyDrive/T5/tokenizer/')
question_model = question_model.to(device)
# Out:
# time: 9.15 s (started: 2023-04-13 17:46:13 +00:00)

# %%
def get_question(context,answer,model,tokenizer):
  text = "context: {} answer: {}".format(context,answer)
  encoding = tokenizer.encode_plus(text,max_length=384, pad_to_max_length=False,truncation=True, return_tensors="pt").to(device)
  input_ids, attention_mask = encoding["input_ids"], encoding["attention_mask"]

  outs = model.generate(input_ids=input_ids,
                                  attention_mask=attention_mask,
                                  early_stopping=True,
                                  num_beams=5,
                                  num_return_sequences=1,
                                  no_repeat_ngram_size=2,
                                  max_length=72)


  dec = [tokenizer.decode(ids,skip_special_tokens=True) for ids in outs]


  Question = dec[0].replace("question:","")
  Question= Question.strip()
  return Question



for wrp in wrap(summarized_text, 150):
  print (wrp)
print ("\n")

for answer in imp_keywords:
  ques = get_question(summarized_text,answer,question_model,question_tokenizer)
  print (ques)
  print (answer.capitalize())
  print ("\n")

for answer in imp_keywords:
  ques = get_question(summarized_text,answer,question_model,question_tokenizer)
  translater = Translator()
  hques = translater.translate(ques, dest="hi")
  print(hques.text)
  hanswer = translater.translate(answer, dest="hi")
  print(hanswer.text)
  print ("\n")
# Out:
# Elon musk tweets that he is working with developers to improve transaction efficiency. The world's largest cryptocurrency fell to a two-month low,
# while dogecoin there was an increase of about 20 percent. Many twitter users welcomed the statement, saying it is time for people to understand that
# crypto is "here to stay" the spacex ceo has tweeted frequently in recent months in support of dogecomin, but rarely for bitcoin.
#
#
# Who tweeted that he is working with developers to improve transaction efficiency?
# Elon musk
#
#
# What was an increase of about 20 percent?
# Dogecoin
#
#
# What is the world's largest cryptocurrency?
# Bitcoin
#
#
# What is Elon musk doing to improve transaction efficiency?
# Tweets
#
#
# किसने ट्वीट किया कि वह लेन-देन दक्षता में सुधार के लिए डेवलपर्स के साथ काम कर रहा है?
# एलोन मस्क
#
#
# लगभग 20 प्रतिशत की वृद्धि क्या थी?
# dogecoin
#
#
# दुनिया की सबसे बड़ी क्रिप्टोकरेंसी कौन सी है?
# Bitcoin
#
#
# ...

# %% [markdown]
# # **Gradio UI Visualization**

# %%
## for english
import gradio as gr

context = gr.inputs.Textbox(lines=10, placeholder="Enter paragraph/content here...")
output = gr.outputs.HTML(  label="Question and Answers")


def generate_question(context):
  summary_text = summarizer(context,summary_model,summary_tokenizer)
  for wrp in wrap(summary_text, 150):
    print (wrp)
  np =  get_keywords(context,summary_text)
  print ("\n\nNoun phrases",np)
  output=""
  for answer in np:
    ques = get_question(summary_text,answer,question_model,question_tokenizer)
    # output= output + ques + "\n" + "Ans: "+answer.capitalize() + "\n\n"
    output = output + "<b style='color:blue;'>" + ques + "</b>"
    # output = output + "<br>"
    output = output + "<b style='color:green;'>" + "Ans: " +answer.capitalize()+  "</b>"
    output = output + "<br>"

  summary ="Summary: "+ summary_text
  for answer in np:
    summary = summary.replace(answer,"<b>"+answer+"</b>")
    summary = summary.replace(answer.capitalize(),"<b>"+answer.capitalize()+"</b>")
  output = output + "<p>"+summary+"</p>"
  
  return output

iface = gr.Interface(
  fn=generate_question, 
  inputs=context, 
  outputs=output)
iface.launch(debug=True)
# Out:
# IMPORTANT: You are using gradio version 3.0.20, however version 3.14.0 is available, please upgrade.
# --------
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://b2f678db17acbf5e.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://www.huggingface.co/spaces)
# <div><iframe src="https://b2f678db17acbf5e.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# A young girl named anna saw swan swimming in the forest. She promised to help the princess and began to think of ways to break the curse. As they
# exchanged their vows, the prince transformed back into human princesses. Cnn's ireport.com: do you know someone who can break this curse? Nominations
# are open for 2013 clinton awards.
# ...

# %%
# !pip install --quiet gradio==3.0.20
# Out:
# time: 9.17 s (started: 2023-04-13 18:42:51 +00:00)

# %%
## for hindi
import gradio as gr

context1 = gr.inputs.Textbox(lines=10, placeholder="Enter paragraph/content here...")

from googletrans import Translator
translater = Translator()
texxt1 = translater.translate(context1, dest="en")
context = texxt1.text

output = gr.outputs.HTML(  label="Question and Answers")


def generate_question(context):
  summary_text = summarizer(context,summary_model,summary_tokenizer)
  for wrp in wrap(summary_text, 150):
    print (wrp)
  np =  get_keywords(context,summary_text)
  print ("\n\nNoun phrases",np)
  output=""
  for answer in np:
    ques = get_question(summary_text,answer,question_model,question_tokenizer)
    translater = Translator()
    # output= output + ques + "\n" + "Ans: "+answer.capitalize() + "\n\n"
    ##output = output + "<b style='color:blue;'>" + ques + "</b>"
    hques = translater.translate(ques, dest="hi")
    output = output + "<b style='color:blue;'>" + hques.text + "</b>"
    output = output + "<br>"
   ## output = output + "<b style='color:green;'>" + "Ans: " +answer.capitalize()+  "</b>"
    hanswer = translater.translate(answer, dest="hi")
    output = output + "<b style='color:green;'>" + "Ans: " +hanswer.text+  "</b>"
    output = output + "<br>"

  summary ="Summary: "+ summary_text
  for answer in np:
    summary = summary.replace(answer,"<b>"+answer+"</b>")
    summary = summary.replace(answer.capitalize(),"<b>"+answer.capitalize()+"</b>")

  translater = Translator()
  hsum = translater.translate(summary, dest="hi")
  output = output + "<p>"+hsum.text+"</p>"
  return output

iface = gr.Interface(
  fn=generate_question, 
  inputs=context, 
  outputs=output)
iface.launch(debug=True)
# Out:
# /content/drive/MyDrive/colab_env/lib/python3.9/site-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /content/drive/MyDrive/colab_env/lib/python3.9/site-packages/gradio/deprecation.py:40: UserWarning: `numeric` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /content/drive/MyDrive/colab_env/lib/python3.9/site-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-c1885ab06170> in <cell line: 44>()
#      42   return output
#      43
# ---> 44 iface = gr.Interface(
#      45   fn=generate_question,
#      46   inputs=context,
#
# ...

# %%
import gradio as gr
from googletrans import Translator
context1 = gr.inputs.Textbox(lines=10, placeholder="Enter paragraph/content here...")


# Get user input and translate it
translator = Translator()
context = translator.translate(context1, dest="en").text
# Pass the translated text to the function
processed_text = generate_question(context)
print("Processed text:", processed_text)


# translater = Translator()
# texxt1 = translater.translate(context1, dest="en")
context = texxt1.text

output = gr.outputs.HTML(  label="Question and Answers")


# def generate_question(context):
#   summary_text = summarizer(context,summary_model,summary_tokenizer)
#   for wrp in wrap(summary_text, 150):
#     print (wrp)
#   np =  get_keywords(context,summary_text)
#   print ("\n\nNoun phrases",np)
#   output=""
#   for answer in np:
#     ques = get_question(summary_text,answer,question_model,question_tokenizer)
#     translater = Translator()
#     # output= output + ques + "\n" + "Ans: "+answer.capitalize() + "\n\n"
#     ##output = output + "<b style='color:blue;'>" + ques + "</b>"
#     hques = translater.translate(ques, dest="hi")
#     output = output + "<b style='color:blue;'>" + hques.text + "</b>"
#     output = output + "<br>"
#    ## output = output + "<b style='color:green;'>" + "Ans: " +answer.capitalize()+  "</b>"
#     hanswer = translater.translate(answer, dest="hi")
#     output = output + "<b style='color:green;'>" + "Ans: " +hanswer.text+  "</b>"
#     output = output + "<br>"

#   summary ="Summary: "+ summary_text
#   for answer in np:
#     summary = summary.replace(answer,"<b>"+answer+"</b>")
#     summary = summary.replace(answer.capitalize(),"<b>"+answer.capitalize()+"</b>")

#   translater = Translator()
#   hsum = translater.translate(summary, dest="hi")
#   output = output + "<p>"+hsum.text+"</p>"
#   return output

# iface = gr.Interface(
#   fn=generate_question, 
#   inputs=context, 
#   outputs=output)
# iface.launch(debug=True)

def generate_question(context):
  summary_text = summarizer(context,summary_model,summary_tokenizer)
  for wrp in wrap(summary_text, 150):
    print (wrp)
  np =  get_keywords(context,summary_text)
  print ("\n\nNoun phrases",np)
  output=""
  for answer in np:
    ques = get_question(summary_text,answer,question_model,question_tokenizer)
    translater = Translator()
    # output= output + ques + "\n" + "Ans: "+answer.capitalize() + "\n\n"
    ##output = output + "<b style='color:blue;'>" + ques + "</b>"
    hques = translater.translate(ques, dest="hi")
    output = output + "<b style='color:blue;'>" + hques.text + "</b>"
    output = output + "<br>"
   ## output = output + "<b style='color:green;'>" + "Ans: " +answer.capitalize()+  "</b>"
    hanswer = translater.translate(answer, dest="hi")
    output = output + "<b style='color:green;'>" + "Ans: " +hanswer.text+  "</b>"
    output = output + "<br>"

  summary ="Summary: "+ summary_text
  for answer in np:
    summary = summary.replace(answer,"<b>"+answer+"</b>")
    summary = summary.replace(answer.capitalize(),"<b>"+answer.capitalize()+"</b>")

  translater = Translator()
  hsum = translater.translate(summary, dest="hi")
  output = output + "<p>"+hsum.text+"</p>"
  return output

# %% [markdown]
# # **Filter keywords with Maximum marginal Relevance**

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# !wget https://github.com/explosion/sense2vec/releases/download/v1.0.0/s2v_reddit_2015_md.tar.gz
# !tar -xvf  s2v_reddit_2015_md.tar.gz

# %%
import numpy as np
from sense2vec import Sense2Vec
s2v = Sense2Vec().from_disk('s2v_old')
# Out:
# time: 6.24 s (started: 2023-04-13 17:46:47 +00:00)

# %%
#!pip install --quiet transformers==4.8.1
#!pip install --quiet sentencepiece==0.1.95
# !pip install --quiet sentence-transformers==2.2.2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 67.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.4 MB/s eta 0:00:00
# ...
# time: 13.9 s (started: 2023-04-13 17:50:21 +00:00)

# %%
from sentence_transformers import SentenceTransformer
# paraphrase-distilroberta-base-v1
sentence_transformer_model = SentenceTransformer('msmarco-distilbert-base-v3')
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.71k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/545 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/265M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/499 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# time: 57.6 s (started: 2023-04-13 17:50:40 +00:00)

# %%
from similarity.normalized_levenshtein import NormalizedLevenshtein
normalized_levenshtein = NormalizedLevenshtein()

def filter_same_sense_words(original,wordlist):
  filtered_words=[]
  base_sense =original.split('|')[1] 
  print (base_sense)
  for eachword in wordlist:
    if eachword[0].split('|')[1] == base_sense:
      filtered_words.append(eachword[0].split('|')[0].replace("_", " ").title().strip())
  return filtered_words

def get_highest_similarity_score(wordlist,wrd):
  score=[]
  for each in wordlist:
    score.append(normalized_levenshtein.similarity(each.lower(),wrd.lower()))
  return max(score)

def sense2vec_get_words(word,s2v,topn,question):
    output = []
    print ("word ",word)
    try:
      sense = s2v.get_best_sense(word, senses= ["NOUN", "PERSON","PRODUCT","LOC","ORG","EVENT","NORP","WORK OF ART","FAC","GPE","NUM","FACILITY"])
      most_similar = s2v.most_similar(sense, n=topn)
      # print (most_similar)
      output = filter_same_sense_words(sense,most_similar)
      print ("Similar ",output)
    except:
      output =[]

    threshold = 0.6
    final=[word]
    checklist =question.split()
    for x in output:
      if get_highest_similarity_score(final,x)<threshold and x not in final and x not in checklist:
        final.append(x)
    
    return final[1:]

def mmr(doc_embedding, word_embeddings, words, top_n, lambda_param):

    # Extract similarity within words, and between words and the document
    word_doc_similarity = cosine_similarity(word_embeddings, doc_embedding)
    word_similarity = cosine_similarity(word_embeddings)

    # Initialize candidates and already choose best keyword/keyphrase
    keywords_idx = [np.argmax(word_doc_similarity)]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    for _ in range(top_n - 1):
        # Extract similarities within candidates and
        # between candidates and selected keywords/phrases
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # Calculate MMR
        mmr = (lambda_param) * candidate_similarities - (1-lambda_param) * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # Update keywords & candidates
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]
# Out:
# time: 2.03 s (started: 2023-04-13 17:52:06 +00:00)

# %%
from collections import OrderedDict
from sklearn.metrics.pairwise import cosine_similarity

def get_distractors_wordnet(word):
    distractors=[]
    try:
      syn = wn.synsets(word,'n')[0]
      
      word= word.lower()
      orig_word = word
      if len(word.split())>0:
          word = word.replace(" ","_")
      hypernym = syn.hypernyms()
      if len(hypernym) == 0: 
          return distractors
      for item in hypernym[0].hyponyms():
          name = item.lemmas()[0].name()
          #print ("name ",name, " word",orig_word)
          if name == orig_word:
              continue
          name = name.replace("_"," ")
          name = " ".join(w.capitalize() for w in name.split())
          if name is not None and name not in distractors:
              distractors.append(name)
    except:
      print ("Wordnet distractors not found")
    return distractors

def get_distractors (word,origsentence,sense2vecmodel,sentencemodel,top_n,lambdaval):
  distractors = sense2vec_get_words(word,sense2vecmodel,top_n,origsentence)
  print ("distractors ",distractors)
  if len(distractors) ==0:
    return distractors
  distractors_new = [word.capitalize()]
  distractors_new.extend(distractors)
  # print ("distractors_new .. ",distractors_new)

  embedding_sentence = origsentence+ " "+word.capitalize()
  # embedding_sentence = word
  keyword_embedding = sentencemodel.encode([embedding_sentence])
  distractor_embeddings = sentencemodel.encode(distractors_new)

  # filtered_keywords = mmr(keyword_embedding, distractor_embeddings,distractors,4,0.7)
  max_keywords = min(len(distractors_new),5)
  filtered_keywords = mmr(keyword_embedding, distractor_embeddings,distractors_new,max_keywords,lambdaval)
  # filtered_keywords = filtered_keywords[1:]
  final = [word.capitalize()]
  for wrd in filtered_keywords:
    if wrd.lower() !=word.lower():
      final.append(wrd.capitalize())
  final = final[1:]
  return final

sent = "What cryptocurrency did Musk rarely tweet about?"
keyword = "Bitcoin"

# sent = "What did Musk say he was working with to improve system transaction efficiency?"
# keyword= "Dogecoin"


# sent = "What company did Musk say would not accept bitcoin payments?"
# keyword= "Tesla"


# sent = "What has Musk often tweeted in support of?"
# keyword = "Cryptocurrency"

print (get_distractors(keyword,sent,s2v,sentence_transformer_model,40,0.2))
# Out:
# word  Bitcoin
# PERSON
# Similar  ['Litecoin', 'Bitcoins', 'Dogecoin', 'Bitcoin', 'Coinbase']
# distractors  ['Dogecoin', 'Coinbase']
# ['Dogecoin', 'Coinbase']
# time: 2.27 s (started: 2023-04-13 17:52:16 +00:00)

# %%
# !pip install --quiet gradio==3.0.20

# %% [markdown]
# # **Gradio Visualization with MCQs**

# %%
import gradio as gr
from googletrans import Translator
translater = Translator()

context = gr.inputs.Textbox(lines=10, placeholder="Enter paragraph/content here...")
output = gr.outputs.HTML(label="Question and Answers")
radiobutton = gr.inputs.Radio(["Wordnet", "Sense2Vec"])


def generate_question(context, radiobutton):
    summary_text = summarizer(context, summary_model, summary_tokenizer)
    for wrp in wrap(summary_text, 150):
        print(wrp)
    np = get_keywords(context, summary_text)
    print("\n\nNoun phrases", np)
    output = ""
    translater = Translator()
    for answer in np:
        ques = get_question(summary_text, answer, question_model, question_tokenizer)
        if radiobutton == "Wordnet":
            distractors = get_distractors_wordnet(answer)
        else:
            distractors = get_distractors(answer.capitalize(), ques, s2v, sentence_transformer_model, 40, 0.2)

        hques = translater.translate(ques, dest="hi")
        output += "<b style='color:blue;'>" + hques.text + "</b><br>"

        hanswer = translater.translate(answer, dest="hi")
        output += "<b style='color:green;'>" + "Ans: " + hanswer.text + "</b><br>"

        if len(distractors) > 0:
            for distractor in distractors[:4]:
                hdist = translater.translate(distractor, dest="hi")
                output += "<b style='color:brown;'>" + hdist.text + "</b><br>"
        output += "<br>"

    summary = "Summary: " + summary_text
    for answer in np:
        summary = summary.replace(answer, "<b>" + answer + "</b><br>")
        summary = summary.replace(answer.capitalize(), "<b>" + answer.capitalize() + "</b>")
        translater = Translator()

    hsum = translater.translate(summary, dest="hi")
    output += "<p>" + hsum.text + "</p><br>"
    return output


iface = gr.Interface(
    fn=generate_question,
    inputs=[context, radiobutton],
    outputs=output)
iface.launch(debug=True)

# %%
from transformers import pipeline
from summarizer import Summarizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet as wn
from gensim.models import KeyedVectors
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import random
from googletrans import Translator
import spacy
import itertools
import re

# Load models and libraries
stop_words = set(stopwords.words('english'))
summary_model = Summarizer()
summary_tokenizer = pipeline('summarization')

nlp = spacy.load("en_core_web_sm")
question_model = pipeline('question-answering', model='mrm8488/bert-small-finetuned-squadv2')
question_tokenizer = question_model.tokenizer
s2v = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True)
sentence_transformer_model = SentenceTransformer('msmarco-distilbert-base-v2')

# Define utility functions
def get_keywords(context, summary_text):
    keywords = []
    # Use spaCy to extract noun phrases
    doc = nlp(context)
    for chunk in doc.noun_chunks:
        if chunk.text in summary_text and len(chunk.text) > 1 and chunk.text.lower() not in stop_words:
            keywords.append(chunk.text)
    return keywords


def get_question(summary_text, answer, model, tokenizer):
    # Prepare input for question-answering model
    inputs = {
        'question': 'What is ' + answer + '?',
        'context': summary_text
    }
    # Generate question
    result = model(inputs)
    question = result['answer']
    return question


def get_distractors_wordnet(word):
    # Get synsets for the word from WordNet
    synsets = wn.synsets(word)
    distractors = []
    for syn in synsets:
        # Get hypernyms and hyponyms for the synset
        hypernyms = [hypo for hypo in syn.hypernyms()[0].hyponyms()]
        hyponyms = [hypo for hypo in syn.hyponyms()]
        # Combine hypernyms and hyponyms
        combined = hypernyms + hyponyms
        # Extract lemmas for the combined hypernyms and hyponyms
        lemmas = list(itertools.chain(*[syn.lemmas() for syn in combined]))
        # Extract names for the lemmas
        names = [lemma.name() for lemma in lemmas]
        # Add names to distractors list
        for name in names:
            if '_' in name:
                name = ' '.join(name.split('_'))
            if name.lower() != word.lower() and len(name) > 1:
                distractors.append(name)
    # Shuffle distractors and return the first four
    random.shuffle(distractors)
    return distractors[:4]


def get_distractors(answer, ques, s2v, model, num_distractors, threshold):
    # Use sentence-transformer to get embeddings for sentences
    sent_emb = model.encode([ques, answer])
    word_emb = s2v[answer]
    # Compute cosine similarity between answer and each word in Word2Vec vocabulary
    sims = cosine_similarity([word_emb], s2v.vectors)
    # Get indices of most similar words
    indices = sims.argsort()[0][-num_distractors-1:-1]
    distractors = []
    for index in indices:
        word = s2v.index2word[index
